# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle 
from google.colab import files

uploaded = files.upload()
dataset = pd.read_csv('aqi_data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 7].values
X1=dataset.iloc[:,:-1].values

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.99, random_state = 0)
X_test1=X_test
print(len(X_test))
# Out:
#      <input type="file" id="files-ba6697a1-1ca0-4187-8b94-3d82a7d20888" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba6697a1-1ca0-4187-8b94-3d82a7d20888">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aqidataset.csv to aqidataset.csv
# 8295

# %%
labelencoder_X = LabelEncoder()
X[:, 6] = labelencoder_X.fit_transform(X[:, 6])
onehotencoder = OneHotEncoder()
X = onehotencoder.fit_transform(X).toarray()

X = X[:, 1:]
print(len(X))
# Out:
# 8378

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.99, random_state = 0)

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
filename = 'new_model.sav'
pickle.dump(regressor , open(filename, 'wb'))

print(len(X_test))
y_pred = regressor.predict(X_test)
print(len(y_pred))
# Out:
# 8295
# 8295

# %%
for i in range(y_pred.size):
 data = pd.DataFrame([[X_test1[i][0],y_pred[i]]], columns=['Trained model','AQI'])
 data.to_csv('result.csv',mode='a', header=False)

# %%
print(y_pred)
# print(X1[:,0])

plt.scatter(X1[:,1], y , color ='red')
plt.plot(X_test1[:,1], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('PM2.5')
plt.ylabel('AQI')
plt.show()


plt.scatter(X1[:,2], y , color ='red')
plt.plot(X_test1[:,2], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('PM10')
plt.ylabel('AQI')
plt.show()


plt.scatter(X1[:,3], y , color ='red')
plt.plot(X_test1[:,3], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('NO2')
plt.ylabel('AQI')
plt.show()

plt.scatter(X1[:,4], y , color ='red')
plt.plot(X_test1[:,4], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('CO')
plt.ylabel('AQI')
plt.show()

plt.scatter(X1[:,5], y , color ='red')
plt.plot(X_test1[:,5], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('SO2')
plt.ylabel('AQI')
plt.show()

plt.scatter(X1[:,6], y , color ='red')
plt.plot(X_test1[:,6], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('O3')
plt.ylabel('AQI')
plt.show()
# Out:
# [101.76664677 101.76664677 101.76664677 ... 110.51426866 101.76664677
#   95.22855438]
