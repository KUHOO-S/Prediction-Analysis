# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle 
from google.colab import files

uploaded = files.upload()
dataset = pd.read_csv('water_data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 8].values
X1=dataset.iloc[:,:-1].values

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.99, random_state = 1)
X_test1=X_test
print(X_test)
# Out:
#      <input type="file" id="files-0f4b789e-f1e4-465b-ab21-869cbf1db6c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f4b789e-f1e4-465b-ab21-869cbf1db6c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving waterdata.csv to waterdata.csv
# [['R KARUVANNURR AT KARUVANNUR BRIDGE' 28.9 6.4 ... 0.4 121 535]
#  ['KUNDALIKA AT ROHA CITY, MAHARASHTRA' 25.0 6.4 ... 0.6 23 45]
#  ['R PUZHACKAL AT PUZHACKAL BRIDGE' 29.1 4.3 ... 0.4 188 796]
#  ...
#  ['UMKHEN AT WAHKDAIT' 18.8 7.1 ... 5.6 22 48]
#  ['NAGAVALLI AT PENTA U/S, JAYKAYPUR TOWN' 24.8 7.4 ... 0.6 5323 15213]
#  ['R ITHIKKARA AT ITHIKKARA' 23.6 6.1 ... 1.6 243 550]]

# %%
labelencoder_X = LabelEncoder()
X[:, 7] = labelencoder_X.fit_transform(X[:, 5])

onehotencoder = OneHotEncoder()
X = onehotencoder.fit_transform(X).toarray()

X = X[:, 1:]
print(len(X))
# Out:
# 223

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.99, random_state = 1)

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
filename = 'new_model.sav'
pickle.dump(regressor , open(filename, 'wb'))

print(len(X_test))
y_pred = regressor.predict(X_test)
print(len(y_pred))
# Out:
# 221
# 221

# %%
for i in range(y_pred.size):
 data = pd.DataFrame([[X_test1[i][0],y_pred[i]]], columns=['Trained model','BOD'])
 data.to_csv('result.csv',mode='a', header=False)

# %%
print(y_pred)

plt.scatter(X1[:,1], y , color ='red')
plt.plot(X_test1[:,1], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('Temperature.')
plt.ylabel('BOD')
plt.show()

plt.scatter(X1[:,2], y , color ='red')
plt.plot(X_test1[:,2], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('D.O.')
plt.ylabel('BOD')
plt.show()

plt.scatter(X1[:,3], y , color ='red')
plt.plot(X_test1[:,3], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('PH')
plt.ylabel('BOD')
plt.show()

plt.scatter(X1[:,4], y , color ='red')
plt.plot(X_test1[:,4], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('Conductivity')
plt.ylabel('BOD')
plt.show()


plt.scatter(X1[:,5], y , color ='red')
plt.plot(X_test1[:,5], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('N+')
plt.ylabel('BOD')
plt.show()

plt.scatter(X1[:,6], y , color ='red')
plt.plot(X_test1[:,6], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('Fecal Coliform')
plt.ylabel('BOD')
plt.show()

plt.scatter(X1[:,7], y , color ='red')
plt.plot(X_test1[:,7], y_pred, color = 'blue')
plt.title('Results for Linear Regression')
plt.xlabel('Total Coliform')
plt.ylabel('BOD')
plt.show()
# Out:
# [3.15    3.35625 3.15    3.35625 3.15    2.7375  3.15    3.15    3.15
#  3.15    3.15    3.15    3.15    3.15    3.15    3.35625 3.15    3.15
#  3.35625 3.15    3.15    3.15    3.15    3.35625 3.15    3.15    3.15
#  3.15    3.15    3.15    3.15    3.15    3.15    3.15    2.94375 3.15
#  3.15    3.15    3.5625  3.15    3.15    3.15    3.76875 3.15    3.35625
#  3.15    3.15    3.15    3.15    3.15    3.15    3.15    2.94375 3.15
#  3.15    3.76875 3.15    3.5625  3.15    3.15    3.15    3.15    3.15
#  3.35625 3.35625 3.15    3.76875 3.15    3.15    3.5625  2.94375 3.5625
#  3.15    3.15    3.15    2.94375 3.5625  3.15    2.94375 3.5625  3.35625
#  3.15    3.15    3.15    3.15    3.15    3.15    3.35625 3.15    3.15
#  3.35625 3.15    3.15    3.15    3.15    3.15    2.7375  3.15    3.15
#  3.15    3.15    3.35625 3.15    3.15    3.15    3.76875 3.35625 3.15
#  3.15    3.15    3.15    3.15    3.15    3.5625  3.5625  3.15    3.15
#  3.15    3.5625  3.15    3.15    3.15    2.94375 3.15    3.15    3.15
#  3.15    2.94375 3.15    3.15    3.15    3.15    3.15    3.15    3.5625
#  3.15    3.15    3.15    3.15    3.15    3.15    3.5625  3.15    3.35625
#  2.94375 3.15    3.15    3.35625 3.15    3.15    3.35625 3.15    3.15
#  3.15    3.15    3.35625 3.15    3.15    3.35625 3.15    3.15    2.7375
#  3.5625  3.15    3.15    3.15    3.15    2.94375 3.5625  3.5625  3.35625
#  3.15    3.35625 3.15    3.15    3.35625 2.94375 3.15    3.76875 3.35625
#  3.15    3.15    3.15    2.7375  3.15    3.15    3.35625 3.5625  3.15
#  3.15    2.7375  3.15    3.15    3.5625  3.35625 2.94375 3.15    3.15
#  3.5625  3.15    3.35625 3.15    3.35625 3.5625  2.94375 3.5625  3.15
#  3.35625 2.7375  3.15    3.15    3.35625 3.15    2.53125 3.15    3.15
#  2.94375 3.15    3.15    3.15    3.15   ]
